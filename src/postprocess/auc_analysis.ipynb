# %%
from sklearn.metrics import roc_auc_score, accuracy_score, roc_curve
import numpy as np
from matplotlib import pyplot as plt

# %%
plt.style.use('seaborn')
plt.rcParams['axes.grid'] = False
# %matplotlib inline

# %%
a = np.random.rand(60000)
plt.plot(a)

# %%
b = 1*((a > 0.6) | ((a < 0.5) & (a > 0.37)))
# b = np.random.rand(10000)

# %%
auc = roc_auc_score(b, a)
auc
# Out:
# 0.9479404332332099

# %%
acc = accuracy_score(b, a > 0.37)
acc
# Out:
# 0.8998166666666667

# %%
fpr, recall, threshold = roc_curve(b, a)

# Plot ROC curves
plt.subplots(1, figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, recall)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
threshold1
# Out:
# array([1.99997660e+00, 9.99976604e-01, 6.00022354e-01, 5.00024708e-01,
#        3.70002541e-01, 6.78960098e-06])
